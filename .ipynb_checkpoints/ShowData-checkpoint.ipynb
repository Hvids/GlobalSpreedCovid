# %%
import pandas as pd

# %%
countries_data_name = './data/countries.csv'
countries_data = pd.read_csv(countries_data_name)

# %%
countries_data.head()
# Out:
#   iso_alpha2 iso_alpha3  iso_numeric         name  \
# 0         AF        AFG            4  Afghanistan
# 1         AL        ALB            8      Albania
# 2         DZ        DZA           12      Algeria
# 3         AD        AND           20      Andorra
# 4         AO        AGO           24       Angola
#
#                              official_name    ccse_name  density  \
# 0          Islamic Republic of Afghanistan  Afghanistan       60
# 1                      Republic of Albania      Albania      105
# 2  People's Democratic Republic of Algeria      Algeria       18
# 3                  Principality of Andorra      Andorra      164
# 4                       Republic of Angola       Angola       26
#
#    fertility_rate  land_area  median_age  migrants  population  \
# 0             4.6     652860        18.0  -62920.0    38928346
# 1             1.6      27400        36.0  -14000.0     2877797
# 2             3.1    2381740        29.0  -10000.0    43851044
# ...
